# %%
from scipy.sparse import diags
import random
import numpy as np
import scipy as sc
import pandas as pd
import csv
import scipy.linalg as spl
import matplotlib.pyplot as plt
from matplotlib import rc
rc('text', usetex=True)
# %matplotlib inline

import sys
sys.path.insert(0, '../python/')
from opt_utils import *
from grad_utils import *
from ks_utils import *
from simulation_utils import *
from cv_utils import *

# %% [markdown]
# # Generate synethic data

# %%
N = 30 # number of teams
T = 30 # number of seasons/rounds/years
tn = [1] * int(T * N * (N - 1)/2) # number of games between each pair of teams

# %% [markdown]
# ### Gaussian Process

# %%
[alpha,r] = [1,1]
##### get beta here #####
random.seed(0)
np.random.seed(0)
beta_gp = beta_gaussian_process(N, T, mu_parameters = [0,0.1], cov_parameters = [alpha,r], mu_type = 'constant', cov_type = 'toeplitz')
game_matrix_list = get_game_matrix_list(N,T,tn,beta_gp)

# %%
latent = beta_gp
for i in range(N):
    plt.plot(latent[:,i], label="team %d"%i)
plt.xlabel("season number")
plt.ylabel("latent parameter")
plt.legend(loc='upper left', bbox_to_anchor=(1, 1.03, 1, 0))

# %%
data = game_matrix_list # shape: T*N*N

# %%
# true beta
beta_true = beta_gp + 0

# %%
beta_true.shape
# Out:
# (30, 30)

# %% [markdown]
# ## Kernel method

# %% [markdown]
# ## $h = T^{-3/4}$

# %%
T**(-1/4)
# Out:
# 0.42728700639623407

# %%
T, N = data.shape[0:2]
ks_data = kernel_smooth(data,1/6 * T**(-1/5))

# %%
ks_data[1,:,:]
# Out:
# array([[0.00000000e+00, 4.18981370e-01, 2.01131129e-01, 1.53470288e-01,
#         2.81351947e-24, 7.92112163e-01, 4.12866874e-07, 3.39899298e-01,
#         5.26369024e-01, 4.77038998e-03, 3.58033312e-11, 4.18570525e-01,
#         3.89763774e-01, 2.01131129e-01, 3.60427300e-01, 2.63985323e-01,
#         6.40216942e-01, 5.70884956e-09, 3.56600186e-01, 6.25502870e-02,
#         4.12432712e-07, 2.17438989e-01, 4.51616388e-26, 1.70263012e-01,
#         2.45993195e-12, 1.73987021e-05, 6.23751772e-01, 5.02511918e-08,
#         2.14286880e-01, 2.06309463e-01],
#        [5.81018630e-01, 0.00000000e+00, 2.01542341e-01, 5.81243018e-01,
#         1.27682621e-01, 5.44379263e-01, 6.77285701e-02, 8.39330547e-01,
#         5.95659083e-01, 3.25634594e-01, 6.23338082e-01, 2.22617322e-01,
#         4.86522552e-01, 2.34060914e-01, 2.09645608e-01, 3.22065904e-01,
#         6.34429626e-01, 5.17250552e-01, 4.56920938e-02, 3.14442060e-01,
#         6.85557945e-01, 2.19430779e-01, 2.65161898e-01, 5.04260760e-01,
#         5.59935147e-08, 7.60099446e-02, 6.90566837e-01, 6.51150087e-01,
#         5.79555546e-01, 3.46554860e-01],
#        [7.98868871e-01, 7.98457659e-01, 0.00000000e+00, 9.99907609e-01,
#         9.64249158e-01, 9.99907665e-01, 3.71784641e-01, 9.95232099e-01,
#         9.37429007e-01, 2.51587398e-01, 8.40721172e-01, 6.43399859e-01,
#         9.93731685e-01, 8.36046486e-01, 7.31640534e-01, 9.86847090e-01,
#         5.97737741e-01, 9.99999945e-01, 5.77221630e-01, 5.93707043e-01,
#         2.99825226e-01, 2.57880550e-01, 1.21330654e-01, 6.91069915e-01,
#         4.31910294e-01, 6.08323495e-01, 5.68204992e-01, 0.00000000e+00,
#         2.72499439e-01, 4.17458563e-01],
#        [7.85713120e-01, 4.20444454e-01, 1.59186031e-01, 5.97182190e-01,
#         2.68862957e-01, 7.65922100e-01, 3.13789858e-01, 8.22800879e-01,
#         6.75584655e-01, 4.68136410e-01, 6.85948445e-01, 7.28003694e-01,
#         5.00939752e-01, 3.56207203e-01, 6.70160825e-01, 5.78167345e-01,
#         6.90566786e-01, 8.08278049e-01, 3.65570430e-01, 4.68466738e-01,
#         2.02611712e-01, 2.32072376e-01, 2.14659982e-01, 9.67157222e-01,
#         2.67395726e-01, 4.12859103e-01, 7.80948477e-01, 7.27500561e-01,
#         0.00000000e+00, 5.35847893e-01],
#        [7.93690537e-01, 6.53445140e-01, 6.19701243e-01, 6.88806353e-01,
#         6.95297960e-01, 3.73656923e-01, 2.18919928e-01, 5.05812876e-01,
#         5.31136507e-01, 4.76795108e-03, 4.12358864e-01, 3.09036872e-01,
#         7.21308836e-01, 5.26461359e-01, 4.71457276e-01, 2.96041360e-01,
#         8.34155154e-01, 7.85250167e-01, 4.81358354e-01, 1.08212601e-01,
#         1.07816304e-01, 3.09173871e-01, 1.59186025e-01, 5.92524027e-01,
#         2.32206817e-01, 2.06005867e-01, 7.92433931e-01, 5.82541437e-01,
#         4.64152107e-01, 0.00000000e+00]])

# %%
objective_pgd, beta_pgd = gd_bt(data = ks_data,verbose=True)
# Out:
# initial objective value: 9045.570706
# 1-th GD, objective value: 7417.590646
# 2-th GD, objective value: 7343.884287
# 3-th GD, objective value: 7322.316321
# 4-th GD, objective value: 7321.725750
# 5-th GD, objective value: 7321.662251
# 6-th GD, objective value: 7321.653136
# 7-th GD, objective value: 7321.651682
# 8-th GD, objective value: 7321.651437
# 9-th GD, objective value: 7321.651394
# 10-th GD, objective value: 7321.651386
# 11-th GD, objective value: 7321.651384
# 12-th GD, objective value: 7321.651384
# 13-th GD, objective value: 7321.651384
# 14-th GD, objective value: 7321.651384
# 15-th GD, objective value: 7321.651384
# 16-th GD, objective value: 7321.651384
# 17-th GD, objective value: 7321.651384
# 18-th GD, objective value: 7321.651384
# 19-th GD, objective value: 7321.651384
# 20-th GD, objective value: 7321.651384
# 21-th GD, objective value: 7321.651384
# Converged!

# %%
T, N = data.shape[0:2]
beta = beta_pgd.reshape((T,N))
f = plt.figure(1, figsize = (9,5))
ax = plt.subplot(111)
for i in range(N):
    ax.plot(range(1,T + 1),beta[:,i],marker = '.',label = 'Team' + str(i),linewidth=1)

box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])

# Put a legend to the right of the current axis
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.show()
# f.savefig("l2_sq_solution.pdf", bbox_inches='tight')

# %% [markdown]
# ## LOOCV

# %%
import time
start_time = time.time()

random.seed(0)
np.random.seed(0)
h_list = np.linspace(0.2, 0.01, 5)
# h_cv, nll_cv, beta_cv, prob_cv = cv_utils.loocv_ks(data, h_list, gd_bt, num_loocv = 200, return_prob = True, out = "notebook")
h_cv, nll_cv, beta_cv, prob_cv = loocv_ks(data, h_list, gd_bt, num_loocv = 200, return_prob = True, out = "notebook")
loo_nll_DBT, loo_prob_DBT = max(nll_cv), prob_cv[np.argmax(nll_cv)]

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# 
# 178-th cv done
# 179-th cv done
# 180-th cv done
# 181-th cv done
# 182-th cv done
# 183-th cv done
# 184-th cv done
# 185-th cv done
# 186-th cv done
# 187-th cv done
# 188-th cv done
# 189-th cv done
# 190-th cv done
# 191-th cv done
# 192-th cv done
# 193-th cv done
# 194-th cv done
# 195-th cv done
# 196-th cv done
# 197-th cv done
# 198-th cv done
# 199-th cv done
# 200-th cv done
# --- 973.9976234436035 seconds ---

# %%
h_cv
# Out:
# 0.057499999999999996

# %%
f = plt.figure(1, figsize = (7,5))
size_ylabel = 20
size_xlabel = 30
size_tick = 20

nll_cv = nll_cv
plt.plot(h_list[::-1], nll_cv)
plt.xlabel(r'$h$',fontsize = size_xlabel); plt.ylabel(r"Averaged nll",fontsize = size_ylabel)
plt.tick_params(axis='both', which='major', labelsize=size_tick)

# f.savefig("cv_curve.pdf", bbox_inches='tight')

# %%
import time
start_time = time.time()

random.seed(0)
np.random.seed(0)
h = 0.1
nll_DBT, beta_DBT, prob_DBT = loo_DBT(data, h, gd_bt, num_loo = 200, return_prob = True, out = "notebook")

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# 1-th cv done
# 2-th cv done
# 3-th cv done
# 4-th cv done
# 5-th cv done
# 6-th cv done
# 7-th cv done
# 8-th cv done
# 9-th cv done
# 10-th cv done
# 11-th cv done
# 12-th cv done
# 13-th cv done
# 14-th cv done
# 15-th cv done
# 16-th cv done
# 17-th cv done
# 18-th cv done
# 19-th cv done
# 20-th cv done
# 21-th cv done
# 22-th cv done
# 23-th cv done
# 24-th cv done
# 25-th cv done
# 26-th cv done
# 27-th cv done
# 28-th cv done
# 29-th cv done
# 30-th cv done
# 31-th cv done
# 32-th cv done
# 33-th cv done
# 34-th cv done
# 35-th cv done
# 36-th cv done
# 37-th cv done
# 38-th cv done
# 39-th cv done
# 40-th cv done
# 41-th cv done
# 42-th cv done
# 43-th cv done
# 44-th cv done
# 45-th cv done
# 46-th cv done
# 47-th cv done
# 48-th cv done
# 49-th cv done
# 50-th cv done
# 51-th cv done
# 52-th cv done
# 53-th cv done
# 54-th cv done
# 55-th cv done
# 56-th cv done
# 57-th cv done
# 58-th cv done
# 59-th cv done
# 60-th cv done
# 61-th cv done
# 62-th cv done
# 63-th cv done
# 64-th cv done
# 65-th cv done
# 66-th cv done
# 67-th cv done
# 68-th cv done
# 69-th cv done
# 70-th cv done
# 71-th cv done
# 72-th cv done
# 73-th cv done
# 74-th cv done
# 75-th cv done
# 76-th cv done
# 77-th cv done
# 78-th cv done
# 79-th cv done
# 80-th cv done
# 81-th cv done
# 82-th cv done
# 83-th cv done
# 84-th cv done
# 85-th cv done
# 86-th cv done
# 87-th cv done
# 88-th cv done
# 89-th cv done
# 90-th cv done
# 91-th cv done
# 92-th cv done
# 93-th cv done
# 94-th cv done
# 95-th cv done
# 96-th cv done
# 97-th cv done
# 98-th cv done
# 99-th cv done
# 100-th cv done
# 101-th cv done
# 102-th cv done
# 103-th cv done
# 104-th cv done
# 105-th cv done
# 106-th cv done
# 107-th cv done
# 108-th cv done
# 109-th cv done
# 110-th cv done
# 111-th cv done
# 112-th cv done
# 113-th cv done
# 114-th cv done
# 115-th cv done
# 116-th cv done
# 117-th cv done
# 118-th cv done
# 119-th cv done
# 120-th cv done
# 121-th cv done
# 122-th cv done
# 123-th cv done
# 124-th cv done
# 125-th cv done
# 126-th cv done
# 127-th cv done
# 128-th cv done
# 129-th cv done
# 130-th cv done
# 131-th cv done
# 132-th cv done
# 133-th cv done
# 134-th cv done
# 135-th cv done
# 136-th cv done
# 137-th cv done
# 138-th cv done
# 139-th cv done
# 140-th cv done
# 141-th cv done
# 142-th cv done
# 143-th cv done
# 144-th cv done
# 145-th cv done
# 146-th cv done
# 147-th cv done
# 148-th cv done
# 149-th cv done
# 150-th cv done
# 151-th cv done
# 152-th cv done
# 153-th cv done
# 154-th cv done
# 155-th cv done
# 156-th cv done
# 157-th cv done
# 158-th cv done
# 159-th cv done
# 160-th cv done
# 161-th cv done
# 162-th cv done
# 163-th cv done
# 164-th cv done
# 165-th cv done
# 166-th cv done
# 167-th cv done
# 168-th cv done
# 169-th cv done
# 170-th cv done
# 171-th cv done
# 172-th cv done
# 173-th cv done
# 174-th cv done
# 175-th cv done
# 176-th cv done
# 177-th cv done
# 178-th cv done
# 179-th cv done
# 180-th cv done
# 181-th cv done
# 182-th cv done
# 183-th cv done
# 184-th cv done
# 185-th cv done
# 186-th cv done
# 187-th cv done
# 188-th cv done
# 189-th cv done
# 190-th cv done
# 191-th cv done
# 192-th cv done
# 193-th cv done
# 194-th cv done
# 195-th cv done
# 196-th cv done
# 197-th cv done
# 198-th cv done
# 199-th cv done
# 200-th cv done
# --- 192.7256143093109 seconds ---

# %%
# winrate
random.seed(0)
np.random.seed(0)
winrate = get_winrate(data)
loo_nll_wr, loo_prob_wr = loo_winrate(data)

# %%
loo_prob_wr
# Out:
# 0.4408928571428572

# %%
# vanilla BT
import time
start_time = time.time()

random.seed(0)
np.random.seed(0)
objective_vanilla_bt, beta_vanilla_bt = gd_bt(data = data,verbose = True)
loo_nll_vBT, loo_prob_vBT = loo_vBT(data,num_loo = 200)

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# initial objective value: 9045.570706
# 1-th GD, objective value: 6914.839888
# 2-th GD, objective value: 6724.320055
# 3-th GD, objective value: 6715.880998
# 4-th GD, objective value: 6713.313569
# 5-th GD, objective value: 6713.212612
# 6-th GD, objective value: 6713.152219
# 7-th GD, objective value: 6713.111726
# 8-th GD, objective value: 6713.104434
# 9-th GD, objective value: 6713.101115
# 10-th GD, objective value: 6713.098464
# 11-th GD, objective value: 6713.097859
# 12-th GD, objective value: 6713.097295
# 13-th GD, objective value: 6713.097152
# 14-th GD, objective value: 6713.097026
# 15-th GD, objective value: 6713.096991
# 16-th GD, objective value: 6713.096963
# 17-th GD, objective value: 6713.096954
# 18-th GD, objective value: 6713.096947
# 19-th GD, objective value: 6713.096945
# 20-th GD, objective value: 6713.096944
# 21-th GD, objective value: 6713.096943
# 22-th GD, objective value: 6713.096943
# 23-th GD, objective value: 6713.096943
# 24-th GD, objective value: 6713.096943
# 25-th GD, objective value: 6713.096943
# 26-th GD, objective value: 6713.096943
# 27-th GD, objective value: 6713.096943
# 28-th GD, objective value: 6713.096943
# 29-th GD, objective value: 6713.096943
# 30-th GD, objective value: 6713.096943
# 31-th GD, objective value: 6713.096943
# 32-th GD, objective value: 6713.096943
# 33-th GD, objective value: 6713.096943
# 34-th GD, objective value: 6713.096943
# 35-th GD, objective value: 6713.096943
# 36-th GD, objective value: 6713.096943
# 37-th GD, objective value: 6713.096943
# 38-th GD, objective value: 6713.096943
# 39-th GD, objective value: 6713.096943
# Converged!
# --- 4.642187833786011 seconds ---

# %%
loo_nll_vBT
# Out:
# 0.6266419986139994

# %%
loo_prob_vBT
# Out:
# 0.36976343734769335

# %%
rank_dif_estimator = [0] * 3
beta_all = [winrate,beta_vanilla_bt,beta_cv]
for i in range(len(rank_dif_estimator)):
    betai = beta_all[i]
    rank_dif_estimator[i] = np.mean(av_dif_rank(beta_true,betai))
rank_dif_estimator

df = pd.DataFrame({'estimator':['winrate','vanilla BT','DBT'],'average rank difference':rank_dif_estimator,
                  'LOO Prob':[loo_prob_wr,loo_prob_vBT,loo_prob_DBT],
                   'LOO nll':[loo_nll_wr,loo_nll_vBT,loo_nll_DBT]})

# %%
print(df.to_latex(index_names=True, escape=False, index=False, 
                          column_format='c|c|c|c|', float_format="{:0.2f}".format,
                          header=True, bold_rows=True))
# Out:
# \begin{tabular}{c|c|c|c|}
# \toprule
#  LOO Prob &  LOO nll &  average rank difference &   estimator \\
# \midrule
#      0.44 &     0.00 &                     2.80 &     winrate \\
#      0.37 &     0.63 &                     2.78 &  vanilla BT \\
#      0.37 &     0.61 &                     1.74 &         DBT \\
# \bottomrule
# \end{tabular}

# %%
T, N = data.shape[0:2]
f = plt.figure(1, figsize = (10,8))

size_ylabel = 20
size_xlabel = 15
size_title = 15
size_tick = 13
size_legend = 15.4
font_title = "Times New Roman Bold"

random.seed(0)
np.random.seed(0)
color_matrix = c=np.random.rand(N,3)

beta = beta_true.reshape((T,N))
ax = plt.subplot(221)
for i in range(N):
    ax.plot(range(1,T + 1),beta[:,i],c=color_matrix[i,:],marker = '.',label = 'Team' + str(i),linewidth=1)
    ax.tick_params(axis='both', which='major', labelsize=size_tick)
    plt.title(r"True $\beta^*$",fontsize = size_title)
    plt.xlabel(r"$t$",fontsize = size_xlabel); plt.ylabel(r"${\beta}^*$",fontsize = size_ylabel,rotation = "horizontal")
    bottom, top = plt.ylim()
    
beta = beta_cv.reshape((T,N))
ax = plt.subplot(222)
for i in range(N):
    ax.plot(range(1,T + 1),beta[:,i],c=color_matrix[i,:],marker = '.',label = 'Team' + str(i),linewidth=1)
    ax.tick_params(axis='both', which='major', labelsize=size_tick)
    plt.title(r"Dynamic Bradley-Terry, Gaussian Kernel",fontsize = size_title)
    plt.xlabel(r"$t$",fontsize = size_xlabel); plt.ylabel(r"$\hat{\beta}$",fontsize = size_ylabel,rotation = "horizontal")
#     plt.ylim((bottom, top))


beta = winrate.reshape((T,N))
ax = plt.subplot(223)
for i in range(N):
    ax.plot(range(1,T + 1),beta[:,i],c=color_matrix[i,:],marker = '.',label = 'Team' + str(i),linewidth=1)
    ax.tick_params(axis='both', which='major', labelsize=size_tick)
    plt.title(r"Win Rate",fontsize = size_title)
    plt.xlabel("t",fontsize = size_xlabel); plt.ylabel(r"Win Rate",fontsize = 10,rotation = "vertical")


ax.legend(loc='lower left', fontsize = size_legend,labelspacing = 0.75,bbox_to_anchor=(-0.03,-0.6),ncol = 5)


beta = beta_vanilla_bt.reshape((T,N))
ax = plt.subplot(224)
for i in range(N):
    ax.plot(range(1,T + 1),beta[:,i],c=color_matrix[i,:],marker = '.',label = 'Team' + str(i),linewidth=1)
    ax.tick_params(axis='both', which='major', labelsize=size_tick)
    plt.title(r"Original Bradley-Terry",fontsize = size_title)
    plt.xlabel(r"$t$",fontsize = size_xlabel); plt.ylabel(r"$\hat{\beta}$",fontsize = size_ylabel,rotation = "horizontal")
    

plt.subplots_adjust(hspace = 0.3)
plt.show()
# f.savefig("compare.pdf", bbox_inches='tight')

# %% [markdown]
# ## repeated experiment

# %%
import time
start_time = time.time()

random.seed(0)
np.random.seed(0)
B = 20
loo_ks = 200
loo = 200
h_cv_list = []
rank_diff_DBT_list, loo_nll_DBT_list, loo_prob_DBT_list = [], [], []
rank_diff_wr_list, loo_nll_wr_list, loo_prob_wr_list = [], [], []
rank_diff_vBT_list, loo_nll_vBT_list, loo_prob_vBT_list = [], [], []

for b in range(B):
    N = 30 # number of teams
    T = 30 # number of seasons/rounds/years
    tn = [1] * int(T * N * (N - 1)/2) # number of games between each pair of teams

    [alpha,r] = [1,1]
    ##### get beta here #####
    beta_gp = beta_gaussian_process(N, T, mu_parameters = [0,0.1], 
                                    cov_parameters = [alpha,r], mu_type = 'constant', cov_type = 'toeplitz')
    game_matrix_list = get_game_matrix_list(N,T,tn,beta_gp)

    data = game_matrix_list # shape: T*N*N

    # true beta
    beta_true = beta_gp + 0

#     # ks cv
#     h_list = np.linspace(0.2, 0.01, 10)
#     h_cv, nll_cv, beta_cv, prob_cv = loocv_ks(data, h_list, gd_bt, num_loocv = loo_ks, verbose = False,
#                                               return_prob = True, out = "notebook")
#     h_cv_list.append(h_cv)
#     loo_nll_DBT_list.append(max(nll_cv)) 
#     loo_prob_DBT_list.append(prob_cv[np.argmax(nll_cv)])
#     rank_diff_DBT_list.append(np.mean(av_dif_rank(beta_true,beta_cv)))
    
    # fixed h
    h_cv = 1/12 * T**(-1/5)
    nll_cv, beta_cv, prob_cv = loo_DBT(data, h_cv, gd_bt, num_loo = 200, return_prob = True, out = "notebook")

    h_cv_list.append(h_cv)
    loo_nll_DBT_list.append(nll_cv) 
    loo_prob_DBT_list.append(prob_cv)
    rank_diff_DBT_list.append(np.mean(av_dif_rank(beta_true,beta_cv)))
    
    
    
    winrate = get_winrate(data)
    loo_nll_wr, loo_prob_wr = loo_winrate(data,num_loo = loo)
    loo_nll_wr_list.append(loo_nll_wr)
    loo_prob_wr_list.append(loo_prob_wr)
    rank_diff_wr_list.append(np.mean(av_dif_rank(beta_true,winrate)))
    
    objective_vanilla_bt, beta_vBT = gd_bt(data = data)
    loo_nll_vBT, loo_prob_vBT = loo_vBT(data,num_loo = loo)
    loo_nll_vBT_list.append(loo_nll_vBT)
    loo_prob_vBT_list.append(loo_prob_vBT)
    rank_diff_vBT_list.append(np.mean(av_dif_rank(beta_true,beta_vBT)))
    
    print(str(b) + '-th repeat finished.')
    print("--- %s seconds ---" % (time.time() - start_time))
    
    
rank_dif_estimator = [np.mean(rank_diff_wr_list),
                     np.mean(rank_diff_vBT_list),
                     np.mean(rank_diff_DBT_list)]
loo_prob_wr = np.mean(loo_prob_wr_list)
loo_prob_vBT = np.mean(loo_prob_vBT_list)
loo_prob_DBT = np.mean(loo_prob_DBT_list)


loo_nll_wr = np.mean(loo_nll_wr_list)
loo_nll_vBT = np.mean(loo_nll_vBT_list)
loo_nll_DBT = np.mean(loo_nll_DBT_list)

df = pd.DataFrame({'estimator':['winrate','vanilla BT','DBT'],'average rank difference':rank_dif_estimator,
                  'LOO Prob':[loo_prob_wr,loo_prob_vBT,loo_prob_DBT],
                   'LOO nll':[loo_nll_wr,loo_nll_vBT,loo_nll_DBT]})


print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# 0-th repeat finished.
# --- 1959.1274116039276 seconds ---
# 1-th repeat finished.
# --- 3877.8936388492584 seconds ---
# 2-th repeat finished.
# --- 5730.4429936409 seconds ---
# 3-th repeat finished.
# --- 7613.673355579376 seconds ---
# 4-th repeat finished.
# --- 9467.276326179504 seconds ---
# 5-th repeat finished.
# --- 11332.797498464584 seconds ---
# 6-th repeat finished.
# --- 16368.29775094986 seconds ---
# 7-th repeat finished.
# --- 21333.701483011246 seconds ---
# 8-th repeat finished.
# --- 23295.45072555542 seconds ---
# 9-th repeat finished.
# --- 25738.380514621735 seconds ---
# 10-th repeat finished.
# --- 30204.368246793747 seconds ---
# 11-th repeat finished.
# --- 32171.947192192078 seconds ---
# 12-th repeat finished.
# --- 34374.25936317444 seconds ---
# 13-th repeat finished.
# --- 36438.910210609436 seconds ---
# 14-th repeat finished.
# --- 42289.547921180725 seconds ---
# 15-th repeat finished.
# --- 47537.447805166245 seconds ---
# 16-th repeat finished.
# --- 49939.14178085327 seconds ---
# 17-th repeat finished.
# --- 54853.896929979324 seconds ---
# 18-th repeat finished.
# --- 56492.461467027664 seconds ---
# 19-th repeat finished.
# --- 58678.027700185776 seconds ---
# --- 58678.02969908714 seconds ---

# %%
rank_dif_estimator = [np.mean(rank_diff_wr_list),
                     np.mean(rank_diff_vBT_list),
                     np.mean(rank_diff_DBT_list)]
loo_prob_wr = np.mean(loo_prob_wr_list)
loo_prob_vBT = np.mean(loo_prob_vBT_list)
loo_prob_DBT = np.mean(loo_prob_DBT_list)


loo_nll_wr = np.mean(loo_nll_wr_list)
loo_nll_vBT = np.mean(loo_nll_vBT_list)
loo_nll_DBT = np.mean(loo_nll_DBT_list)

df = pd.DataFrame({'estimator':['winrate','vanilla BT','DBT'],'average rank difference':rank_dif_estimator,
                  'LOO Prob':[loo_prob_wr,loo_prob_vBT,loo_prob_DBT],
                   'LOO nll':[loo_nll_wr,loo_nll_vBT,loo_nll_DBT]})

# %%
print(df.to_latex(index_names=True, escape=False, index=False, 
                          column_format='c|c|c|c|', float_format="{:0.2f}".format,
                          header=True, bold_rows=True))
# Out:
# \begin{tabular}{c|c|c|c|}
# \toprule
#  LOO Prob &  LOO nll &  average rank difference &   estimator \\
# \midrule
#      0.43 &     0.00 &                     2.85 &     winrate \\
#      0.37 &     0.59 &                     2.85 &  vanilla BT \\
#      0.38 &     0.60 &                     1.91 &         DBT \\
# \bottomrule
# \end{tabular}

# %%
f = plt.figure(1, figsize = (16,8))

size_ylabel = 20
size_xlabel = 15
size_title = 15
size_tick = 13
size_legend = 15.4
font_title = "Times New Roman Bold"

random.seed(0)
np.random.seed(0)
color_list = ['red','blue','green']
x_range = [i for i in range(B)]

ax = plt.subplot(311)
ax.plot(x_range,rank_diff_wr_list,c=color_list[0],marker = '.',label = 'win rate',linewidth=1)
ax.plot(x_range,rank_diff_vBT_list,c=color_list[1],marker = '.',label = 'vBT',linewidth=1)
ax.plot(x_range,rank_diff_DBT_list,c=color_list[2],marker = '.',label = 'DBT',linewidth=1)

ax.tick_params(axis='both', which='major', labelsize=size_tick)
plt.title(r"average rank difference over 20 repeats (N,T=30,n=1)",fontsize = size_title)
plt.xlabel(r"Repeat",fontsize = size_xlabel); plt.ylabel(r"ave. rank diff.",fontsize = size_ylabel,rotation = "vertical")
ax.legend(loc='upper left', fontsize = size_legend,labelspacing = 0.75,ncol = 1)
    
ax = plt.subplot(312)
ax.plot(x_range,loo_nll_vBT_list,c=color_list[1],marker = '.',label = 'vBT',linewidth=1)
ax.plot(x_range,loo_nll_DBT_list,c=color_list[2],marker = '.',label = 'DBT',linewidth=1)

ax.tick_params(axis='both', which='major', labelsize=size_tick)
plt.title(r"LOO nll over 20 repeats (N,T=30,n=1)",fontsize = size_title)
plt.xlabel(r"Repeat",fontsize = size_xlabel); plt.ylabel(r"LOO nll",fontsize = size_ylabel,rotation = "vertical")
ax.legend(loc='upper left', fontsize = size_legend,labelspacing = 0.75,ncol = 1)

ax = plt.subplot(313)
ax.plot(x_range,loo_prob_wr_list,c=color_list[0],marker = '.',label = 'win rate',linewidth=1)
ax.plot(x_range,loo_prob_vBT_list,c=color_list[1],marker = '.',label = 'vBT',linewidth=1)
ax.plot(x_range,loo_prob_DBT_list,c=color_list[2],marker = '.',label = 'DBT',linewidth=1)

ax.tick_params(axis='both', which='major', labelsize=size_tick)
plt.title(r"LOO prob over 20 repeats (N,T=30,n=1)",fontsize = size_title)
plt.xlabel(r"Repeat",fontsize = size_xlabel); plt.ylabel(r"LOO prob",fontsize = size_ylabel,rotation = "vertical")
ax.legend(loc='upper left', fontsize = size_legend,labelspacing = 0.75,ncol = 1)


plt.subplots_adjust(hspace = 0.6)
plt.show()
f.savefig("perform_NT30_n1_BT.pdf", bbox_inches='tight')

# %%
T, N = data.shape[0:2]
f = plt.figure(1, figsize = (10,8))

size_ylabel = 20
size_xlabel = 15
size_title = 15
size_tick = 13
size_legend = 15.4
font_title = "Times New Roman Bold"

random.seed(0)
np.random.seed(0)
color_matrix = c=np.random.rand(N,3)

beta = beta_true.reshape((T,N))
ax = plt.subplot(221)
for i in range(N):
    ax.plot(range(1,T + 1),beta[:,i],c=color_matrix[i,:],marker = '.',label = 'Team' + str(i),linewidth=1)
    ax.tick_params(axis='both', which='major', labelsize=size_tick)
    plt.title(r"True $\beta^*$",fontsize = size_title)
    plt.xlabel(r"$T$",fontsize = size_xlabel); plt.ylabel(r"${\beta}^*$",fontsize = size_ylabel,rotation = "horizontal")
    bottom, top = plt.ylim()
    
beta = beta_cv.reshape((T,N))
ax = plt.subplot(222)
for i in range(N):
    ax.plot(range(1,T + 1),beta[:,i],c=color_matrix[i,:],marker = '.',label = 'Team' + str(i),linewidth=1)
    ax.tick_params(axis='both', which='major', labelsize=size_tick)
    plt.title(r"Dynamic Bradley-Terry, Gaussian Kernel",fontsize = size_title)
    plt.xlabel(r"$T$",fontsize = size_xlabel); plt.ylabel(r"$\hat{\beta}$",fontsize = size_ylabel,rotation = "horizontal")
    plt.ylim((bottom, top))


beta = winrate.reshape((T,N))
ax = plt.subplot(223)
for i in range(N):
    ax.plot(range(1,T + 1),beta[:,i],c=color_matrix[i,:],marker = '.',label = 'Team' + str(i),linewidth=1)
    ax.tick_params(axis='both', which='major', labelsize=size_tick)
    plt.title(r"Win Rate",fontsize = size_title)
    plt.xlabel(r"$T$",fontsize = size_xlabel); plt.ylabel(r"Win Rate",fontsize = 10,rotation = "vertical")


# ax.legend(loc='lower left', fontsize = size_legend,labelspacing = 0.75,bbox_to_anchor=(-0.03,-0.6),ncol = 5)


beta = beta_vBT.reshape((T,N))
ax = plt.subplot(224)
for i in range(N):
    ax.plot(range(1,T + 1),beta[:,i],c=color_matrix[i,:],marker = '.',label = 'Team' + str(i),linewidth=1)
    ax.tick_params(axis='both', which='major', labelsize=size_tick)
    plt.title(r"Vanilla Bradley-Terry",fontsize = size_title)
    plt.xlabel(r"$T$",fontsize = size_xlabel); plt.ylabel(r"$\hat{\beta}$",fontsize = size_ylabel,rotation = "horizontal")
    

plt.subplots_adjust(hspace = 0.3)
plt.show()
f.savefig("compare_beta_NT30_n1_BT.pdf", bbox_inches='tight')
